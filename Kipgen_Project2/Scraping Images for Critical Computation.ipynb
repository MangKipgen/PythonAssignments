# %% [markdown]
# ## Pseudo Code
# Import Beautiful soup
#
# variable response = get (Pages to scrap from)
#
# Variable name = beautifulsoupe(get response, html parser)
#
# #### find class with images url
# scrape = select (.class with img url)
#
# #### extract url
# for url in scrape:
# link.get(image source)
#
# append('https:' to the image source)
#
# //download function for the images
#
# def download(full image path):
#     try:
#         retrieve(full image path)
#         sleep time(1,5)
#     except urllib.err
#         print(err.code)
#
# ####  for url in links:
#     fileName = 'img' + '.jpg'
#     save file in = existing folder images/
#
# #### run download
#
#     download(full path)

# %%
import requests

#joy face
response = requests.get("https://generated.photos/faces/young-adult/white-race/joy/female")
#neutral face
# response = requests.get("https://generated.photos/faces/young-adult/white-race/neutral/female")

# %%
# response.text
# Out:
# '<!doctype html>\n<html data-n-head-ssr lang="en-US" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en-US%22%7D%7D">\n<head>\n  <title>Young White Joy Female images | Generated.photos</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="width=device-width, initial-scale=1"><meta data-n-head="ssr" name="format-detection" content="telephone=no"><meta data-n-head="ssr" name="robots" content="noodp"><meta data-n-head="ssr" http-equiv="X-UA-Compatible" content="IE=edge, chrome=1"><meta data-n-head="ssr" name="description" data-hid="description" content="Find Young White Joy Female photos in our free library of AI generated faces."><meta data-n-head="ssr" name="twitter:card" data-hid="twitter:card" content="summary_large_image"><meta data-n-head="ssr" name="twitter:url" data-hid="twitter:url" content="https://icons8.com"><meta data-n-head="ssr" name="twitter:title" data-hid="twitter:title" content="Young White Joy Female images | Generated.photos"><me
# ...

# %%
# Beautifulsoup Library

import bs4 
soup = bs4.BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en-US%22%7D%7D" data-n-head-ssr="" lang="en-US">
# <head>
# ...

# %%
image_info = soup.select('.checkbox')
image_info

# %%
for image in trial:
    get= link.get('height')
print(get)
# Out:
# None

# %%
dwn=link.get('src')
# Out:
# None

# %%
len(image_info)
# Out:
# 1

# %%
# links for the thumbnails 

links = []
for link in image_info:
    #the links is in the 'src' attribute 
    item =link.get('src')
    #we're adding https: to format it properly 
    print(item)
    
    #this if statement is bc some <div> tags also have the class "thumbnail"
    if type(item) is str: 
        print(type(item))
        links.append("https:"+item)
# Out:
# None

# %%
links
# Out:
# []

# %%
import urllib.request
import urllib.parse
from urllib.error import HTTPError
import time
import random as r

# %%
def download(url, full_path):
    try:
        urllib.request.urlretrieve(url, full_path)
        time.sleep(r.randint(1, 5))
    except urllib.error.HTTPError as err:
        print(err.code)
        pass

# %%
for index, url in enumerate(links):
    print(url)
    file_name = 'img_' + str(index) + '.jpg'
    file_path = 'Images/'    
    full_path = '{}{}'.format(file_path, file_name)
    print(file_name)
    download(url, full_path)
# Out:
# https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Mendipsnationaltrust.JPG/220px-Mendipsnationaltrust.JPG
# img_0.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/0/04/Paul%2C_George_%26_John.png/260px-Paul%2C_George_%26_John.png
# img_1.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/97/John_Lennon_%28cropped%29.jpg/130px-John_Lennon_%28cropped%29.jpg
# img_2.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/1/1d/The_Beatles_i_H%C3%B6torgscity_1963.jpg/220px-The_Beatles_i_H%C3%B6torgscity_1963.jpg
# img_3.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-362c46f8491e> in <module>
#       5     full_path = '{}{}'.format(file_path, file_name)
#       6     print(file_name)
# ----> 7     download(url, full_path)
#
# <ipython-input-20-7edae0717945> in download(url, full_path)
#       2     try:
# ...
