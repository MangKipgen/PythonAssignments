# %%
#scraping books & covers of a specific genre 

import requests
response = requests.get ("https://streeteasy.com/building/plg-123-linden-boulevard-brooklyn/6m?featured=1")
# response = requests.get ("http://books.toscrape.com/catalogue/category/books/mystery_3/index.html")

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <title>Access to this page has been denied.</title>
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans:300" rel="stylesheet">
#     <style>
#         html, body {
#             margin: 0;
#             padding: 0;
#             font-family: 'Open Sans', sans-serif;
#             color: #000;
#         }
#
#         a {
#             color: #c5c5c5;
#             text-decoration: none;
#         }
#
#         .container {
#             align-items: center;
#             display: flex;
#             flex: 1;
#             justify-content: space-between;
#             flex-direction: column;
#             height: 100%;
#         }
#
#         .container > div {
#             width: 100%;
#             display: flex;
#             justify-content: center;
#         }
#
#         .container > div > div {
# ...

# %%
import bs4
scrape = bs4.BeautifulSoup(response.text, 'html.parser')

# %%
scrape.select('.product_pod')
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="../../../its-only-the-himalayas_981/index.html"><img alt="It's Only the Himalayas" class="thumbnail" src="../../../../media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/></a>
#  </div>
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">It's Only the Himalayas</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£45.17</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
category = []
for cat in scrape.select('.product_pod'):
    category.append(cat.text)
category
# type(category)
# Out:
# ["\n\n\n\n\n\n\n\n\n\n\nIt's Only the Himalayas\n\nÂ£45.17\n\n\n    \n        In stock\n    \n\n\nAdd to basket\n\n\n",
#  '\n\n\n\n\n\n\n\n\n\n\nFull Moon over Noahâ\x80\x99s ...\n\nÂ£49.43\n\n\n    \n        In stock\n    \n\n\nAdd to basket\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\nSee America: A Celebration ...\n\nÂ£48.87\n\n\n    \n        In stock\n    \n\n\nAdd to basket\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\nVagabonding: An Uncommon Guide ...\n\nÂ£36.94\n\n\n    \n        In stock\n    \n\n\nAdd to basket\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\nUnder the Tuscan Sun\n\nÂ£37.33\n\n\n    \n        In stock\n    \n\n\nAdd to basket\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\nA Summer In Europe\n\nÂ£44.34\n\n\n    \n        In stock\n    \n\n\nAdd to basket\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\nThe Great Railway Bazaar\n\nÂ£30.54\n\n\n    \n        In stock\n    \n\n\nAdd to basket\n\n\n',
#  '\n\n\n\n\n\n\n\n\n\n\nA Year in Provence ...\n\nÂ£56.88\n\n\n    \n        In stock\n    \n\n\nAdd to basket\n\n\n',
# ...

# %%
#strip
newCat = [] 
for nc in category: 
    newCat.append(nc.replace("\n", "")) 
    
newCat
# Out:
# ["It's Only the HimalayasÂ£45.17            In stock    Add to basket",
#  'Full Moon over Noahâ\x80\x99s ...Â£49.43            In stock    Add to basket',
#  'See America: A Celebration ...Â£48.87            In stock    Add to basket',
#  'Vagabonding: An Uncommon Guide ...Â£36.94            In stock    Add to basket',
#  'Under the Tuscan SunÂ£37.33            In stock    Add to basket',
#  'A Summer In EuropeÂ£44.34            In stock    Add to basket',
#  'The Great Railway BazaarÂ£30.54            In stock    Add to basket',
#  'A Year in Provence ...Â£56.88            In stock    Add to basket',
#  'The Road to Little ...Â£23.21            In stock    Add to basket',
#  'Neither Here nor There: ...Â£38.95            In stock    Add to basket',
#  '1,000 Places to See ...Â£26.08            In stock    Add to basket']

# %%
import pandas as pd

newCat_df = pd.DataFrame()
newCat_df['Travel Books'] = pd.Series(newCat).values

newCat_df
# Out:
#                                          Travel Books
# 0   It's Only the HimalayasÂ£45.17            In s...
# 1   Full Moon over Noahâs ...Â£49.43            ...
# 2   See America: A Celebration ...Â£48.87         ...
# 3   Vagabonding: An Uncommon Guide ...Â£36.94     ...
# 4   Under the Tuscan SunÂ£37.33            In stoc...
# 5   A Summer In EuropeÂ£44.34            In stock ...
# 6   The Great Railway BazaarÂ£30.54            In ...
# 7   A Year in Provence ...Â£56.88            In st...
# 8   The Road to Little ...Â£23.21            In st...
# 9   Neither Here nor There: ...Â£38.95            ...
# 10  1,000 Places to See ...Â£26.08            In s...

# %%
newCat_df.to_csv('travel.csv')

# image_info = scrape.select('.image_container')
image_info = scrape.select('.thumbnail')

# %%
image_info
# Out:
# [<img alt="It's Only the Himalayas" class="thumbnail" src="../../../../media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/>,
#  <img alt="Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond" class="thumbnail" src="../../../../media/cache/57/77/57770cac1628f4407636635f4b85e88c.jpg"/>,
#  <img alt="See America: A Celebration of Our National Parks &amp; Treasured Sites" class="thumbnail" src="../../../../media/cache/9a/7e/9a7e63f12829df4b43b31d110bf3dc2e.jpg"/>,
#  <img alt="Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel" class="thumbnail" src="../../../../media/cache/d5/bf/d5bf0090470b0b8ea46d9c166f7895aa.jpg"/>,
#  <img alt="Under the Tuscan Sun" class="thumbnail" src="../../../../media/cache/98/c2/98c2e95c5fd1a4e7cd5f2b63c52826cb.jpg"/>,
#  <img alt="A Summer In Europe" class="thumbnail" src="../../../../media/cache/4e/15/4e15150388702ebca2c5a523ac270539.jpg"/>,
# ...

# %%
links = []
for link in image_info:
    item = link.get('src')
#     print(item)
    links.append("http://books.toscrape.com/"+item)
print(links)
# Out:
# ['http://books.toscrape.com/../../../../media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg', 'http://books.toscrape.com/../../../../media/cache/57/77/57770cac1628f4407636635f4b85e88c.jpg', 'http://books.toscrape.com/../../../../media/cache/9a/7e/9a7e63f12829df4b43b31d110bf3dc2e.jpg', 'http://books.toscrape.com/../../../../media/cache/d5/bf/d5bf0090470b0b8ea46d9c166f7895aa.jpg', 'http://books.toscrape.com/../../../../media/cache/98/c2/98c2e95c5fd1a4e7cd5f2b63c52826cb.jpg', 'http://books.toscrape.com/../../../../media/cache/4e/15/4e15150388702ebca2c5a523ac270539.jpg', 'http://books.toscrape.com/../../../../media/cache/76/de/76de41867f323d7f1f4fbe2fdfc1b2ba.jpg', 'http://books.toscrape.com/../../../../media/cache/db/46/db46159b05faa5d95262112bf9c29ddd.jpg', 'http://books.toscrape.com/../../../../media/cache/e0/4f/e04f8eda2a2fa947aec17640202d9ab0.jpg', 'http://books.toscrape.com/../../../../media/cache/06/81/0681530a7bc301caf5c3257e1b0f0750.jpg', 'http://books.toscrape.com/../../../.
# ...

# %%
import urllib.request
import urllib.parse
from urllib.error import HTTPError
import time
import random as r

def download(url, full_path):
    try:
        urllib.request.urlretrieve(url, full_path)
        time.sleep(r.randint(1, 5))
    except urllib.error.HTTPError as err:
        print(err.code)
        pass
    
for index, url in enumerate(links):
    file_name = 'img_' + str(index) + '.jpg'
    file_path = 'Images/'    
    full_path = '{}{}'.format(file_path, file_name)
    print(file_name)
    download(url, full_path)
# Out:
# http://books.toscrape.com/../../../../media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# img_0.jpg
# 400
# http://books.toscrape.com/../../../../media/cache/57/77/57770cac1628f4407636635f4b85e88c.jpg
# img_1.jpg
# 400
# http://books.toscrape.com/../../../../media/cache/9a/7e/9a7e63f12829df4b43b31d110bf3dc2e.jpg
# img_2.jpg
# 400
# http://books.toscrape.com/../../../../media/cache/d5/bf/d5bf0090470b0b8ea46d9c166f7895aa.jpg
# img_3.jpg
# 400
# http://books.toscrape.com/../../../../media/cache/98/c2/98c2e95c5fd1a4e7cd5f2b63c52826cb.jpg
# img_4.jpg
# 400
# http://books.toscrape.com/../../../../media/cache/4e/15/4e15150388702ebca2c5a523ac270539.jpg
# img_5.jpg
# 400
# http://books.toscrape.com/../../../../media/cache/76/de/76de41867f323d7f1f4fbe2fdfc1b2ba.jpg
# img_6.jpg
# 400
# http://books.toscrape.com/../../../../media/cache/db/46/db46159b05faa5d95262112bf9c29ddd.jpg
# img_7.jpg
# 400
# http://books.toscrape.com/../../../../media/cache/e0/4f/e04f8eda2a2fa947aec17640202d9ab0.jpg
# ...
